# %% [markdown]
# # SUPERMARKET SALES

# %% [markdown]
# The sales of a supermarket are increasing which located at a populated city.The dataset contain the sales of a supermarket which is situated in an city having 3 barnches for 3 months.There are features to analyse the data they are:
# Invoice id: Computer generated sales slip invoice identification number.
#
# - Branch: Main branches in city named as A, B and C.
#
# - City: Location in supermarket in city.
#
# - Customer type: Type of customers, named as " Members " for customers having  member card and " Normal " for without member                      card.
#
# - Gender: Gender type of customer.
#
# - Product line: Category in groups - Electronic accessories, Fashion accessories, Food and beverages, Health and                                                      beauty Home and lifestyle, Sports and travel.
#
# - Unit price: Price of each product in $.
#
# - Quantity: Number of products purchased by customer.
#
# - Tax: 5% tax fee for customer buying.
#
# - Total: Total price including tax.
#
# - Date: Date of purchase (Record available from January 2019 to March 2019).
#
# - Time: Purchase time (10am to 9pm).
#
# - Payment: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet).
#
# - COGS: Cost of goods sold.
#
# - Gross margin percentage: Gross margin percentage.
#
# - Gross income: Gross income.
#
# - Rating: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('supermarket_sales.csv')
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# - There are No null values in the dataset.

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
df.describe(include='O')
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1000   1000    1000          1000    1000                 1000
# unique         1000      3       3             2       2                    6
# top     750-67-8428      A  Yangon        Member  Female  Fashion accessories
# freq              1    340     340           501     501                  178
#
#             Date   Time  Payment
# count       1000   1000     1000
# unique        89    506        3
# top     2/7/2019  19:48  Ewallet
# freq          20      7      345

# %% [markdown]
# - Dropping the first column (Invoice ID) .

# %%
df.drop(df.columns[0],axis=1,inplace=True)

# %% [markdown]
# - value_count() show the count value of the feature

# %% [markdown]
# - For the attribute of the Branch it showing the count value in a specific branches such as A :340,B:332.C:328

# %%
df.Branch.value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %% [markdown]
# - In ths it tells the count vlaue of main areas in the city . It is same as Branch

# %%
df.City.value_counts()
# Out:
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: City, dtype: int64

# %% [markdown]
# # Renaming the column

# %%
df.rename(columns = {'Customer type':'Customer_type'}, inplace = True)

# %%
df.rename(columns = {'Product line':'Product_line'}, inplace = True)

# %%
df.rename(columns={'Unit price':'Unit_price'},inplace=True)

# %%
df.rename(columns={'Tax 5%':'Tax5%'},inplace=True)

# %%
df.rename(columns={'gross margin percentage':'gross_margin_percentage'},inplace=True)

# %%
df.rename(columns={'gross income':'gross_income'},inplace=True)

# %% [markdown]
# - This below code gives the count of the gender that is how many Women and man are contributing for the sales.

# %%
df.Gender.value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %% [markdown]
# - There are 501 out of 1000 Membership holder in the supermarket remaining are the Normal.

# %%
df.Customer_type.value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer_type, dtype: int64

# %% [markdown]
# - Products are divided into 5 catogaries they are:
#    - Fashion accessories
#    - Food and beverages
#    - Electronic accessories
#    - Sports and travel
#    - Home and lifestyle
#    - Health and beauty
# - Maximum sales on the Fashion accessories 178 and Minimum sales on the Health and beauty 152.

# %%
df.Product_line.value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product_line, dtype: int64

# %% [markdown]
# - There are 3 types of Payment methods are used they are:
#   - Ewallet
#   - Cash
#   - Credit card
# - Maximum payment method is used Ewallet 345 and Minimum is Credit card 311.

# %%
df.Payment.value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %% [markdown]
# - The below code is used to convert the Date which is in the datatype 'object' to 'Datetime'.

# %%
df['Date']=pd.to_datetime(df["Date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Branch                   1000 non-null   object
#  1   City                     1000 non-null   object
#  2   Customer_type            1000 non-null   object
#  3   Gender                   1000 non-null   object
#  4   Product_line             1000 non-null   object
#  5   Unit_price               1000 non-null   float64
#  6   Quantity                 1000 non-null   int64
#  7   Tax5%                    1000 non-null   float64
#  8   Total                    1000 non-null   float64
#  9   Date                     1000 non-null   datetime64[ns]
#  10  Time                     1000 non-null   object
#  11  Payment                  1000 non-null   object
#  12  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# - From the Date extracting the month and the week name.

# %%
df['Month_Name']=df.Date.dt.month_name()
df['Day_Name']=df.Date.dt.day_name()

# %% [markdown]
# - In this it is used to convert the Time to datetime and giving the name Hour and making into the whole number

# %%
df['Hour'] = pd.to_datetime(df['Time'], format='%H:%M').dt.hour
hourly_transactions = df.groupby('Hour').size()

all_hours = pd.RangeIndex(start=0, stop=24)
hourly_transactions_full_day = hourly_transactions.reindex(all_hours, fill_value=0)

# %%
#Sum of the sales in a year
sale = df.groupby(df['Date'].dt.year)['Total'].sum()
sale
# Out:
# Date
# 2019    322966.749
# Name: Total, dtype: float64

# %%
#Sum of the sales in Month wise
sales_in_month = df.groupby(['Month_Name'])['Total'].sum()
sales_in_month
# Out:
# Month_Name
# February     97219.374
# January     116291.868
# March       109455.507
# Name: Total, dtype: float64

# %%
#Sum of the sales obtain by male and female
sales_by_gender = df.groupby('Gender')['Total'].sum()
sales_by_gender
# Out:
# Gender
# Female    167882.925
# Male      155083.824
# Name: Total, dtype: float64

# %%
#Sum of the sales obtain in the Specific cities
Sales_in_city=df.groupby('City')['Total'].sum()
Sales_in_city
# Out:
# City
# Mandalay     106197.6720
# Naypyitaw    110568.7065
# Yangon       106200.3705
# Name: Total, dtype: float64

# %%
#Sales According Product Catogeroy
sales_by_product_line = df.groupby('Product_line').agg({'Total': 'sum', 'gross_income': 'sum'})

print(sales_by_product_line)
# Out:
#                              Total  gross_income
# Product_line
# Electronic accessories  54337.5315     2587.5015
# Fashion accessories     54305.8950     2585.9950
# Food and beverages      56144.8440     2673.5640
# Health and beauty       49193.7390     2342.5590
# Home and lifestyle      53861.9130     2564.8530
# Sports and travel       55122.8265     2624.8965

# %%
#Average rating obtain for Products 
average_ratings = df.groupby('Product_line')['Rating'].mean()
average_ratings
# Out:
# Product_line
# Electronic accessories    6.924706
# Fashion accessories       7.029213
# Food and beverages        7.113218
# Health and beauty         7.003289
# Home and lifestyle        6.837500
# Sports and travel         6.916265
# Name: Rating, dtype: float64

# %%
df
# Out:
#     Branch       City Customer_type  Gender            Product_line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit_price  Quantity    Tax5%      Total       Date   Time      Payment  \
# ...

# %% [markdown]
# # EDA

# %%
import seaborn as sns

# %%
plt.figure(figsize = (8,6))
ax=sns.countplot(data = df, x = "Branch",palette ="BuPu")
ax.bar_label(ax.containers[0])
plt.title("Distribution of sales across branches",fontsize=20)
plt.xlabel('Distribution across the branches',fontsize=12)
plt.ylabel("Number of sales",fontsize=12)
plt.show()

# %%
city=df['City'].value_counts()
city
plt.figure(figsize=(6,6))
plt.pie(city,labels=city.index,autopct='%1.1f%%',shadow=True,explode=[0.1,0,0])
plt.title('City Ditrtribution ',fontsize=16)
plt.show()

# %%
Customer = df['Customer_type'].value_counts()
print(Customer)


fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(aspect="equal"))
ax.pie(Customer, labels=Customer.index, autopct='%1.1f%%',shadow=True)
ax.legend( Customer,
          title="Customer",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1),fontsize=16)
plt.title('Customer Type Distribution',fontsize=16)
plt.show()
# Out:
# Member    501
# Normal    499
# Name: Customer_type, dtype: int64

# %%
plt.figure(figsize=(6,6))
axg=sns.countplot(x=df.Gender,palette='Set2')
axg.bar_label(axg.containers[0])
plt.title('Distribution of the Male and Female',fontsize=16)
plt.xlabel('Gender',fontsize=12)
plt.ylabel('Nimber of Sales',fontsize=12)
plt.show()

# %%
plt.figure(figsize=(15,6))
axp=sns.countplot(x=df.Product_line,palette='coolwarm')
axp.bar_label(axp.containers[0])
plt.title('Details of Products',fontsize=16)
plt.xlabel('Products',fontsize=12)
plt.ylabel('Number of Sales',fontsize=12)
plt.show()

# %%
sns.kdeplot(x=df.Unit_price,fill=True,color='r')
# Out:
# <Axes: xlabel='Unit_price', ylabel='Density'>

# %%
quantity = df['Quantity'].value_counts()

fig, bx =plt.subplots(figsize=(6, 6), subplot_kw=dict(aspect="equal"))

bx.pie(quantity, labels=quantity.index, autopct='%1.1f%%', shadow=True,explode = [0, 0, 0.1, 0.1, 0.1, 0.1, 0.2, 0.2, 0.2, 0.2])
bx.legend(title="Quantity", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1), fontsize=15)
plt.title('Quantity Percentage', fontsize=16)
plt.show()

# %%
plt.figure(figsize=(8,6))
axpa=sns.countplot(x=df.Payment,palette='Accent')
axpa.bar_label(axpa.containers[0])
plt.title('Details of Payments',fontsize=16)
plt.xlabel('Payment Method',fontsize=12)
plt.ylabel('Count of Payments',fontsize=12)
plt.show()

# %%
plt.figure(figsize=(15,6))
bx=sns.countplot(x=df.Product_line,  hue=df.Gender,palette='RdYlBu')
for container in bx.containers:
    # Iterate over each bar in the container
    for bar in container:
        # Get the height of the bar (count)
        height = bar.get_height()
        # Annotate the bar with the count value
        bx.annotate(f'{height}', 
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

plt.title('Details of Products based on Gender',fontsize=18)
plt.xlabel('Products',fontsize=14)
plt.ylabel('Number of Sales based on Gender',fontsize=14)
plt.show()

# %% [markdown]
# Number sales of Products based on the Gender.

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x=df.Date,y= df.gross_income,errorbar=None,markers='*')
plt.show()

# %% [markdown]
# It shows sales obtaines across week.

# %%
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']


df['Day_Name'] = pd.Categorical(df['Day_Name'], categories=day_order, ordered=True)
plt.figure(figsize=(10, 6))
sns.lineplot(x='Day_Name', y='gross_income', data=df, marker='o', linestyle='--',errorbar=None,color='r')
plt.xlabel('Day')
plt.ylabel('Gross Income')
plt.title('Gross Income by Day')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(18, 12))
sns.lineplot(x=df['Day_Name'], y=df['gross_income'], errorbar=None,hue=df.Product_line,style=df.Product_line)
plt.show()

# %%
num_col=df.select_dtypes(include = ['float64', 'int64'])
num_col
# Out:
#      Unit_price  Quantity    Tax5%      Total    cogs  \
# 0         74.69         7  26.1415   548.9715  522.83
# 1         15.28         5   3.8200    80.2200   76.40
# 2         46.33         7  16.2155   340.5255  324.31
# 3         58.22         8  23.2880   489.0480  465.76
# 4         86.31         7  30.2085   634.3785  604.17
# ..          ...       ...      ...        ...     ...
# 995       40.35         1   2.0175    42.3675   40.35
# 996       97.38        10  48.6900  1022.4900  973.80
# 997       31.84         1   1.5920    33.4320   31.84
# 998       65.82         1   3.2910    69.1110   65.82
# 999       88.34         7  30.9190   649.2990  618.38
#
#      gross_margin_percentage  gross_income  Rating  Hour
# 0                   4.761905       26.1415     9.1    13
# 1                   4.761905        3.8200     9.6    10
# 2                   4.761905       16.2155     7.4    13
# 3                   4.761905       23.2880     8.4    20
# ...

# %%
cat_col=df.select_dtypes(include = ['object'])
cat_col
# Out:
#     Branch       City Customer_type  Gender            Product_line   Time  \
# 0        A     Yangon        Member  Female       Health and beauty  13:08
# 1        C  Naypyitaw        Normal  Female  Electronic accessories  10:29
# 2        A     Yangon        Normal    Male      Home and lifestyle  13:23
# 3        A     Yangon        Member    Male       Health and beauty  20:33
# 4        A     Yangon        Normal    Male       Sports and travel  10:37
# ..     ...        ...           ...     ...                     ...    ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty  13:46
# 996      B   Mandalay        Normal  Female      Home and lifestyle  17:16
# 997      A     Yangon        Member    Male      Food and beverages  13:22
# 998      A     Yangon        Normal    Male      Home and lifestyle  15:33
# 999      A     Yangon        Member  Female     Fashion accessories  13:28
#
#          Payment Month_Name
# 0        Ewallet    January
# ...

# %%
numerical_features =df.select_dtypes(include=['number'])

num_features = len(numerical_features.columns)
num_rows = 8  # Set the number of rows
num_cols = 5  # Set the number of columns
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(15, 40))
axes = axes.flatten()

for i, column in enumerate(numerical_features.columns):
    if i < num_features:
        sns.boxplot(x=df[column], ax=axes[i])
        axes[i].set_title(f'Box Plot for {column}')

for i in range(len(numerical_features.columns), len(axes)):
    fig.delaxes(axes[i])
    
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,7), dpi=300)
bars = plt.bar(hourly_transactions_full_day.index, hourly_transactions_full_day, color='skyblue')

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, int(yval), ha='center', va='bottom')
    
    
plt.title('Customer Activity by Hour',fontsize=16)
plt.xlabel('Hour of the Day',fontsize=12)
plt.ylabel('Numbers of Transactions',fontsize=12)
plt.xticks(range(0,24))
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# It shows the at what time more sales are obtain.

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
plt.figure(figsize=(20,12))
for i,col in enumerate(num_col.columns, start=1):
    plt.subplot(3,3,i)
    sns.kdeplot(x=col,data=num_col,fill=True,color='g')
    plt.xlabel(col,fontsize=12)
    plt.xticks()
    plt.ylabel('Number of data',fontsize=12)
plt.show()

# %%
cat_col.drop('Time',axis=1,inplace=True)

# %%
plt.figure(figsize=(20,30))
for i,col in enumerate(cat_col.columns, start=1):
    plt.subplot(4,3,i)
    sns.countplot(x=col,data=cat_col, palette="BuGn_r", order = cat_col[col].value_counts().index)
    plt.xlabel(col,fontsize=12)
    plt.xticks()
    plt.ylabel('Number of data',fontsize=12) 
plt.show()

# %% [markdown]
# # LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
for col in cat_col.columns:
    df[col] = encoder.fit_transform(df[col])

# %% [markdown]
# Mapping function is used to convert the day_names to number because it in the form of datetime.

# %%
df.Day_Name=df.Day_Name.map({'Monday':1,'Tuesday':2,'Wednesday':3,'Thursday':4,'Friday':5,'Saturday':6,'Sunday':7})#imputation using map function

# %% [markdown]
# Label Encoding is used to convert the categorical columns to the Numerical .

# %%
df
# Out:
#      Branch  City  Customer_type  Gender  Product_line  Unit_price  Quantity  \
# 0         0     2              0       0             3       74.69         7
# 1         2     1              1       0             0       15.28         5
# 2         0     2              1       1             4       46.33         7
# 3         0     2              0       1             3       58.22         8
# 4         0     2              1       1             5       86.31         7
# ..      ...   ...            ...     ...           ...         ...       ...
# 995       2     1              1       1             3       40.35         1
# 996       1     0              1       0             4       97.38        10
# 997       0     2              0       1             2       31.84         1
# 998       0     2              1       1             4       65.82         1
# 999       0     2              0       0             1       88.34         7
#
# ...

# %%
df.drop(['Date','Time'],axis=1,inplace=True)

# %%
df
# Out:
#      Branch  City  Customer_type  Gender  Product_line  Unit_price  Quantity  \
# 0         0     2              0       0             3       74.69         7
# 1         2     1              1       0             0       15.28         5
# 2         0     2              1       1             4       46.33         7
# 3         0     2              0       1             3       58.22         8
# 4         0     2              1       1             5       86.31         7
# ..      ...   ...            ...     ...           ...         ...       ...
# 995       2     1              1       1             3       40.35         1
# 996       1     0              1       0             4       97.38        10
# 997       0     2              0       1             2       31.84         1
# 998       0     2              1       1             4       65.82         1
# 999       0     2              0       0             1       88.34         7
#
# ...

# %% [markdown]
# # Correlation

# %% [markdown]
# Correlation is to know the strength of the features with one other.

# %%
corr_n =df[['Unit_price','Quantity','Tax5%','Total','cogs','gross_income','Rating']].corr()

plt.figure(figsize=(25,15), dpi=200)

sns.heatmap(corr_n, cmap="Blues",annot=True)
# Out:
# <Axes: >

# %%
df.drop(['gross_margin_percentage'],axis=1,inplace=True)

# %% [markdown]
# ### ---------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #   MODEL EVALUATION

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.model_selection import cross_val_score, KFold, train_test_split

# %%
X = df.drop(['Total'],axis=1)
y = df.Total

# split data to train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 20)

# %%
model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
print(f"train score: {model.score(X_train, y_train)}")
# score for test 
print(f"test score: {model.score(X_test, y_test)}")
# Out:
# train score: 1.0
# test score: 1.0

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)  # RMSE is the square root of MSE
print(f"\nMean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Mean Absolute Error: 1.1032360210568489e-13
# Mean Squared Error: 2.0502558035566516e-26
# Root Mean Squared Error: 1.4318714340179608e-13

# %%
r2 = r2_score(y_test, y_pred)
print(f"Coefficient of Determination (R^2): {r2}")
# Out:
# Coefficient of Determination (R^2): 1.0

# %% [markdown]
# ## we got 100% r2_score
